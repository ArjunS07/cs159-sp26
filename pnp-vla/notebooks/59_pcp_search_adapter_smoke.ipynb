# %% [markdown]
# # PCP-search adapter smoke test
#
# Loads the guarded adapter for tensor-contract inspection. It remains `offline_only` and cannot mutate actions.

# %%
EXTRAS = 'train'
SETUP_ENV = False
import urllib.request
exec(urllib.request.urlopen('https://raw.githubusercontent.com/ArjunS07/cs159-sp26/main/pnp-vla/scripts/colab_bootstrap.py').read().decode())

# %%
from pnp.pcp_critic import PCPSearchAdapter, load_pcp_critic

CRITIC_ID = 'PASTE_PCPC_CRITIC_ID'
assert CRITIC_ID.startswith('pcpc-')
critic, row, payload = load_pcp_critic(CRITIC_ID)
adapter = PCPSearchAdapter(critic)
print({'critic_id': CRITIC_ID, 'safety_status': row['safety_status'], 'adapter_mode': adapter.config.mode})
