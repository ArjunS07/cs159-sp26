# %% [markdown]
# # 101 - SmolVLA A1 stock/refine consensus projection
#
# One worker over the same 400 identities as notebook 96. This is exactly the notebook-96 K=3 stock/refine average-and-project arm, except it executes only one action before replanning. The periodic table includes exact-matched historical A10 stock and A10 K=3 projection. Videos are off.

# %%
# Install NVIDIA EGL before importing MuJoCo.
import re, subprocess
driver = subprocess.check_output(
    ['nvidia-smi','--query-gpu=driver_version','--format=csv,noheader'],
    text=True).splitlines()[0].strip()
package = f"libnvidia-gl-{re.match(r'\d+', driver).group()}"
if subprocess.run('ldconfig -p | grep -q libEGL_nvidia', shell=True).returncode:
    print('Installing NVIDIA EGL package:', package)
    subprocess.run(['apt-get','update','-qq'], check=True)
    subprocess.run(['apt-get','install','-y','--no-install-recommends',package], check=True)
subprocess.run('ldconfig -p | grep libEGL_nvidia', shell=True, check=True)

# %%
EXTRAS = 'sim'
SETUP_ENV = True
import urllib.request
exec(urllib.request.urlopen('https://raw.githubusercontent.com/ArjunS07/cs159-sp26/main/pnp-vla/scripts/colab_bootstrap.py').read().decode())

# %%
from pnp.smolvla_blend_ablation_experiment import (
    SMOLVLA_CONSENSUS_A1_EXPERIMENT,
    run_smolvla_consensus_a1_eval_worker)

ROLLOUT_BATCH_SIZE = 8
print({'experiment': SMOLVLA_CONSENSUS_A1_EXPERIMENT, 'identities': 400,
       'new_rollouts': 400, 'arm': 'stock/refine average -> K3 projection, A1',
       'integration_steps': 10, 'n_action_steps': 1,
       'parent_pnp_steps': [1,2,3], 'parent_pnp_k_by_step': [3,1,1],
       'projection': 's=0.5, K=3', 'print_every_identities': 10,
       'video': 'off'})
run_smolvla_consensus_a1_eval_worker(rollout_batch_size=ROLLOUT_BATCH_SIZE)
