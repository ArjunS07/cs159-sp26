# %% [markdown]
# # 83 - SmolVLA standard-LIBERO A10 worker 0
#
# Shard 0 of 2 over 400 standard-LIBERO identities (10 initial states per task). Each identity runs two matched arms: stock SmolVLA with measurement-only U10/U20/U50 logging, and always-on P&P refinement. Both generate 50 actions with 10 Euler steps and execute exactly 10 actions before replanning. Progress prints every 10 complete two-arm identities; videos and observation frames are off.

# %%
EXTRAS = 'sim'
SETUP_ENV = True
import urllib.request
exec(urllib.request.urlopen('https://raw.githubusercontent.com/ArjunS07/cs159-sp26/main/pnp-vla/scripts/colab_bootstrap.py').read().decode())

# %%
from pnp.experiments import SMOLVLA_LIBERO_EXPERIMENT, run_smolvla_libero_worker

SHARD_COUNT = 2
SHARD_INDEX = 0
ROLLOUT_BATCH_SIZE = 2
print({'experiment': SMOLVLA_LIBERO_EXPERIMENT,
       'shard_count': SHARD_COUNT, 'shard_index': SHARD_INDEX,
       'pilot_identities': 400, 'identities_in_shard': 200,
       'arms': ['stock + U logging', 'always-on refinement'],
       'rollouts_in_shard': 400, 'integration_steps': 10,
       'n_action_steps': 10, 'generated_chunk_size': 50,
       'pnp_k': 5, 'pnp_steps': [3, 4], 'video': 'off'})
run_smolvla_libero_worker(
    shard_count=SHARD_COUNT, shard_index=SHARD_INDEX,
    experiment=SMOLVLA_LIBERO_EXPERIMENT,
    rollout_batch_size=ROLLOUT_BATCH_SIZE)
