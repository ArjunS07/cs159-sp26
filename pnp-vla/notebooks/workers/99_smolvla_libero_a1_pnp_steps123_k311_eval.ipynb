# %% [markdown]
# # 99 - SmolVLA A1 with P&P `(1,2,3)/(3,1,1)`
#
# One worker over the same 400 identities as notebook 98. It applies the notebook-85 P&P refinement schedule—K=3 at Euler step 1 and K=1 at steps 2 and 3—but executes only action 0 before replanning. The periodic table includes historical A10 stock for orientation; the causal refinement comparison is against notebook 98's A1 stock results after both runs complete. Videos are off.

# %%
# Install NVIDIA EGL before importing MuJoCo.
import re, subprocess
driver = subprocess.check_output(
    ['nvidia-smi','--query-gpu=driver_version','--format=csv,noheader'],
    text=True).splitlines()[0].strip()
package = f"libnvidia-gl-{re.match(r'\d+', driver).group()}"
if subprocess.run('ldconfig -p | grep -q libEGL_nvidia', shell=True).returncode:
    print('Installing NVIDIA EGL package:', package)
    subprocess.run(['apt-get','update','-qq'], check=True)
    subprocess.run(['apt-get','install','-y','--no-install-recommends',package], check=True)
subprocess.run('ldconfig -p | grep libEGL_nvidia', shell=True, check=True)

# %%
EXTRAS = 'sim'
SETUP_ENV = True
import urllib.request
exec(urllib.request.urlopen('https://raw.githubusercontent.com/ArjunS07/cs159-sp26/main/pnp-vla/scripts/colab_bootstrap.py').read().decode())

# %%
from pnp.smolvla_a1_experiment import (
    SMOLVLA_A1_PNP_EXPERIMENT, run_smolvla_a1_pnp_eval_worker)

ROLLOUT_BATCH_SIZE = 8
print({'experiment': SMOLVLA_A1_PNP_EXPERIMENT, 'identities': 400,
       'new_rollouts': 400, 'arm': 'A1 P&P (1,2,3)/(3,1,1)',
       'integration_steps': 10, 'n_action_steps': 1,
       'generated_chunk_size': 50, 'pnp_steps': [1,2,3],
       'pnp_k_by_step': [3,1,1],
       'causal_control': 'notebook 98 stock A1',
       'print_every_identities': 10, 'video': 'off'})
run_smolvla_a1_pnp_eval_worker(rollout_batch_size=ROLLOUT_BATCH_SIZE)
