# %% [markdown]
# # 96 - SmolVLA stock/refinement average + projection (K=3 vs K=5)
#
# One paired worker over the exact 400 worker-85 LIBERO identities (state indices 0-9). At each decision it produces the exact stock chunk and the completed `(1,2,3)/(3,1,1)` P&P-refined chunk from the same observation and initial policy noise, averages their continuous arm actions, and preserves stock gripper commands where their signs disagree. It forward-noises that final clean consensus to `s=0.5`, runs either 3 or 5 fixed-time P&P perturbations, and integrates from `s=0.5` to clean before executing exactly 10 actions. The periodic exact-matched table includes both new arms, historical stock from worker 83, and historical `(1,2,3)/(3,1,1)` refinement from worker 85. Videos are off.

# %%
EXTRAS = 'sim'
SETUP_ENV = True
import urllib.request
exec(urllib.request.urlopen('https://raw.githubusercontent.com/ArjunS07/cs159-sp26/main/pnp-vla/scripts/colab_bootstrap.py').read().decode())

# %%
from pnp.smolvla_consensus_projection_experiment import (
    SMOLVLA_CONSENSUS_PROJECTION_EXPERIMENT,
    run_smolvla_consensus_projection_eval_worker)

ROLLOUT_BATCH_SIZE = 8
print({'experiment': SMOLVLA_CONSENSUS_PROJECTION_EXPERIMENT,
       'identities': 400, 'new_rollouts': 800,
       'arms': ['average + project K=3', 'average + project K=5'],
       'parent_refinement': 'P&P steps (1,2,3), K (3,1,1)',
       'projection_s': 0.5, 'integration_steps': 10,
       'n_action_steps': 10, 'generated_chunk_size': 50,
       'references': ['historic stock worker 83', 'historic P&P worker 85'],
       'print_every_identities': 10, 'video': 'off'})
run_smolvla_consensus_projection_eval_worker(
    rollout_batch_size=ROLLOUT_BATCH_SIZE)
