# %% [markdown]
# # 87 — SmolVLA tree-source collection, worker 1/2
#
# Collects 400 identities from the frozen standard-LIBERO indices 10–29 source manifest. The rollout uses the selected `(1,2,3), K=(3,1,1)` P&P policy, executes 10 of 50 predicted actions, and stores exact restoration, uncertainty, and future critic-training artifacts. Indices 0–9 remain the evaluation cohort. Resume-safe; videos are off.

# %%
EXTRAS = 'sim'
SETUP_ENV = True
import urllib.request
exec(urllib.request.urlopen('https://raw.githubusercontent.com/ArjunS07/cs159-sp26/main/pnp-vla/scripts/colab_bootstrap.py').read().decode())

# %%
from pnp.smolvla_tree_source_experiment import (
    SMOLVLA_TREE_SOURCE_EXPERIMENT, run_smolvla_tree_source_worker)

SHARD_COUNT = 2
SHARD_INDEX = 1
ROLLOUT_BATCH_SIZE = 8
print({'experiment': SMOLVLA_TREE_SOURCE_EXPERIMENT,
       'worker': f'{SHARD_INDEX}/{SHARD_COUNT}',
       'source_indices': list(range(10, 30)),
       'identities_in_this_shard': 400,
       'policy': 'P&P steps=(1,2,3), K=(3,1,1)',
       'integration_steps': 10, 'n_action_steps': 10,
       'generated_chunk_size': 50,
       'future_manifest_mix': '65% uncertainty-prioritized / 35% uniform',
       'progress_every_identities': 10, 'video': 'off'})
run_smolvla_tree_source_worker(
    shard_count=SHARD_COUNT, shard_index=SHARD_INDEX,
    rollout_batch_size=ROLLOUT_BATCH_SIZE)
