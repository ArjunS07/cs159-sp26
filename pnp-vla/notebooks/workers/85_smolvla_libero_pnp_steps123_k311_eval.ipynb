# %% [markdown]
# # 85 - SmolVLA LIBERO early P&P schedule evaluation
#
# One worker over the same 400 identities as worker 83. It evaluates always-on P&P with three perturbations at Euler step 1 and one perturbation at each of Euler steps 2 and 3, while reusing exact-matched historical stock outcomes from worker 83. The policy still uses 10 Euler integration steps, generates 50 actions, and executes exactly 10 actions before replanning. Videos are off; exact-matched SR prints every 10 completed identities.

# %%
EXTRAS = 'sim'
SETUP_ENV = True
import urllib.request
exec(urllib.request.urlopen('https://raw.githubusercontent.com/ArjunS07/cs159-sp26/main/pnp-vla/scripts/colab_bootstrap.py').read().decode())

# %%
from pnp.smolvla_followup_experiments import (
    SMOLVLA_SCHEDULE_EXPERIMENT, run_smolvla_schedule_eval_worker)

ROLLOUT_BATCH_SIZE = 8
print({'experiment': SMOLVLA_SCHEDULE_EXPERIMENT,
       'identities': 400, 'new_rollouts': 400,
       'reference': 'exact-matched historic stock from worker 83',
       'integration_steps': 10, 'n_action_steps': 10,
       'generated_chunk_size': 50, 'pnp_steps': [1, 2, 3],
       'pnp_k_by_step': [3, 1, 1], 'video': 'off'})
run_smolvla_schedule_eval_worker(rollout_batch_size=ROLLOUT_BATCH_SIZE)
