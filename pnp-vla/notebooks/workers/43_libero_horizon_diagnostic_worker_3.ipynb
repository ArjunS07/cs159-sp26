# %% [markdown]
# # 43 - Standard LIBERO U10/U20/U50 diagnostic worker 3
#
# Shard 3 of 4 over the corrected 400-identity standard-LIBERO cohort. This runs one no-op K=5 probe arm at Euler steps (3,4), executes 10 actions before replanning, and logs U10/U20/U50, consecutive contraction, PCP/Q features, and executed trajectories. Approximately 100 rollouts. Progress prints every 25 new rollouts with current and corrected historical SR plus diagnostic means.

# %%
EXTRAS = 'sim'
SETUP_ENV = True
import urllib.request
exec(urllib.request.urlopen('https://raw.githubusercontent.com/ArjunS07/cs159-sp26/main/pnp-vla/scripts/colab_bootstrap.py').read().decode())

# %%
from pnp.experiments import (LIBERO_HORIZON_DIAGNOSTICS_EXPERIMENT,
    run_libero_horizon_diagnostic_worker)

SHARD_COUNT = 4
SHARD_INDEX = 3
print({'experiment': LIBERO_HORIZON_DIAGNOSTICS_EXPERIMENT,
       'shard_count': SHARD_COUNT, 'shard_index': SHARD_INDEX,
       'identities_in_shard': 100, 'rollouts_in_shard': 100,
       'n_action_steps': 10, 'pnp_k': 5, 'pnp_steps': [3, 4],
       'diagnostics': ['U10', 'U20', 'U50', 'contraction', 'PCP/Q']})
run_libero_horizon_diagnostic_worker(
    shard_count=SHARD_COUNT, shard_index=SHARD_INDEX,
    experiment=LIBERO_HORIZON_DIAGNOSTICS_EXPERIMENT)
