# %% [markdown]
# # PCP-search initial survey
#
# Read-only provenance and difficulty survey. Collection policy remains in `pnp.pcp_search`.

# %%
EXTRAS = 'sim'
SETUP_ENV = False
import urllib.request
exec(urllib.request.urlopen('https://raw.githubusercontent.com/ArjunS07/cs159-sp26/main/pnp-vla/scripts/colab_bootstrap.py').read().decode())

# %%
from pnp.pcp_search.survey import collect_initial_survey, render_initial_survey

survey = collect_initial_survey()
print(render_initial_survey(survey))
survey
