# %% [markdown]
# # PCP critic preflight and immutable snapshot
#
# Creates an immutable, train-eligible-only dataset snapshot. It streams one artifact at a time for validation/action statistics, so it does not retain rollout prefixes or images in RAM. It never trains or evaluates a policy.

# %%
EXTRAS = 'sim'
SETUP_ENV = False
import urllib.request
exec(urllib.request.urlopen('https://raw.githubusercontent.com/ArjunS07/cs159-sp26/main/pnp-vla/scripts/colab_bootstrap.py').read().decode())

# %%
from pnp.pcp_critic import create_dataset_snapshot

SNAPSHOT_NAME = 'pcp-critic-smoke-400'
SNAPSHOT_ID = create_dataset_snapshot(name=SNAPSHOT_NAME, seed=42, train_fraction=0.80)
print(SNAPSHOT_ID)
