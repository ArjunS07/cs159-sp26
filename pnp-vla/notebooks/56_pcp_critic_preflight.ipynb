# %% [markdown]
# # PCP critic preflight and immutable snapshot
#
# Creates an immutable, train-eligible-only dataset snapshot. The scan downloads only the action field needed for statistics, retries transient storage failures, and checkpoints progress to Drive every 10 rollouts. It never trains or evaluates a policy.

# %%
EXTRAS = 'sim'
SETUP_ENV = False
import urllib.request
exec(urllib.request.urlopen('https://raw.githubusercontent.com/ArjunS07/cs159-sp26/main/pnp-vla/scripts/colab_bootstrap.py').read().decode())

# %%
from google.colab import drive
drive.mount('/content/drive')

from pnp.pcp_critic.resumable_snapshot import create_resumable_dataset_snapshot

SNAPSHOT_NAME = 'qplanning-existing-data-v1'
PROGRESS_PATH = '/content/drive/MyDrive/pnp_qplanning_corrector/snapshot_progress_qplanning_existing_data_v1.json'
SNAPSHOT_ID = create_resumable_dataset_snapshot(
    name=SNAPSHOT_NAME, progress_path=PROGRESS_PATH,
    seed=42, train_fraction=0.80)
print('immutable snapshot:', SNAPSHOT_ID)
