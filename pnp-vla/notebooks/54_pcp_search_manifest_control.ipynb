# %% [markdown]
# # PCP-search manifest control
#
# Freeze the approved PRO partition or one evidence-driven standard adaptive tranche. This is the only manifest-mutating notebook.

# %%
EXTRAS = 'sim'
SETUP_ENV = False
import urllib.request
exec(urllib.request.urlopen('https://raw.githubusercontent.com/ArjunS07/cs159-sp26/main/pnp-vla/scripts/colab_bootstrap.py').read().decode())

# %%
from pnp.pcp_search.control import publish_pro_partition, publish_pro_sentinels, publish_standard_adaptive

# Freeze and run these 8+6 sentinels first. Only release the full manifests after all validate.
PRO_SENTINELS = publish_pro_sentinels()
print('sentinels:', PRO_SENTINELS)

# Then freeze the full 640/160 partition. Publishing is content-addressed and idempotent.
# PRO_MANIFESTS = publish_pro_partition()
# print('full partition:', PRO_MANIFESTS)

# After the preceding standard manifest is training-ready, uncomment exactly one tranche at a time.
# STANDARD_PARENT_MANIFEST_ID = 'pcps-c810651498933ba955c51560'
# STANDARD_TRANCHE_ID = publish_standard_adaptive(
#     parent_manifest_id=STANDARD_PARENT_MANIFEST_ID, tranche_index=1)
# print(STANDARD_TRANCHE_ID)
