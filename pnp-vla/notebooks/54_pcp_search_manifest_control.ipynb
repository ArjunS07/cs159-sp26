# %% [markdown]
# # PCP-search manifest control
#
# Freeze one approved collection manifest at a time. Follow `libero_collection_plan.md`; this is the only manifest-mutating notebook.

# %%
EXTRAS = 'sim'
SETUP_ENV = False
import urllib.request
exec(urllib.request.urlopen('https://raw.githubusercontent.com/ArjunS07/cs159-sp26/main/pnp-vla/scripts/colab_bootstrap.py').read().decode())

# %%
from pnp.pcp_search.control import (
    publish_fresh_pro_train, publish_fresh_pro_train_sentinel, publish_standard_adaptive,
)

# Run exactly one coordinator action at a time. The four-worker instructions are in
# libero_collection_plan.md.

# Phase 1: standard adaptive 200.
# STANDARD_TRANCHE_ID = publish_standard_adaptive(
#     parent_manifest_id='pcps-c810651498933ba955c51560', tranche_index=1)
# print(STANDARD_TRANCHE_ID)

# Phase 2: fresh PRO eight-row sentinel. Run and validate it before phase 3.
# FRESH_PRO_SENTINEL_ID = publish_fresh_pro_train_sentinel()
# print(FRESH_PRO_SENTINEL_ID)

# Phase 3: fresh PRO train 640.
# FRESH_PRO_TRAIN_ID = publish_fresh_pro_train()
# print(FRESH_PRO_TRAIN_ID)
